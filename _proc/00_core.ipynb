# %% [raw]
# ---
# description: Fill in a module description here
# output-file: core.html
# title: core
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#|output: asis
#| echo: false
show_doc(find_equilibrium)
# Out:
# ---
#
# [source](https://github.com/nshea3/intromicropy/blob/main/intromicropy/core.py#L21){target="_blank" style="float:right; font-size:smaller"}
#
# ### find_equilibrium
#
# >      find_equilibrium (sf, df)

# %%
#|output: asis
#| echo: false
show_doc(demand)
# Out:
# ---
#
# [source](https://github.com/nshea3/intromicropy/blob/main/intromicropy/core.py#L14){target="_blank" style="float:right; font-size:smaller"}
#
# ### demand
#
# >      demand (expr:str)

# %%
#|output: asis
#| echo: false
show_doc(supply)
# Out:
# ---
#
# [source](https://github.com/nshea3/intromicropy/blob/main/intromicropy/core.py#L7){target="_blank" style="float:right; font-size:smaller"}
#
# ### supply
#
# >      supply (expr:str)

# %%
pd = demand("-1.0*Q_d + 400.0")
pd
# Out:
# 400.0 - 1.0*Q_d

# %%
ps = supply("Q_s")
ps
# Out:
# Q_s

# %%
find_equilibrium(ps, pd)
# Out:
# (200.000000000000, 200.000000000000)
